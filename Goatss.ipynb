# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO
import os
from datetime import datetime
import uuid

# Load the YOLOv8 model
model = YOLO('best.pt')

# Open the video file
#video_path = "C:\\Users\\soumy\\Downloads\\videoplayback.mp4"
video_path = "pexels-anastasia-shuraeva-7671385 (2160p).mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])

# Create a folder for saving tracked information with current date and time
output_folder_root = "tracked_info"
output_folder_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
os.makedirs(output_folder_root, exist_ok=True)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, conf=0.3, iou=0.5, tracker="bytetrack.yaml")
        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            track_ids = results[0].boxes.id.cpu().numpy().astype(int)
            confidences = results[0].boxes.conf.cpu().numpy().astype(int)
            class_names = results[0].names
        # Get the boxes and track IDs
        # boxes = results[0].boxes.xywh.cpu()
        # track_ids = results[0].boxes.id.int().cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks and save cropped images with random filenames
        for box, track_id, class_name in zip(boxes, track_ids, class_names):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

            # Crop the region of interest
            roi = frame[y:h, x:w]

            img_count = len(track)
            if img_count < 60:
                # Save the cropped image with a random unique filename
                unique_filename = str(uuid.uuid4())[:8]  # Using a portion of a UUID as a unique identifier
                tracker_folder = os.path.join(output_folder_root, output_folder_datetime, f"tracker_{track_id}")
                os.makedirs(tracker_folder, exist_ok=True)
                filename = f"{unique_filename}.jpg"
                output_path = os.path.join(tracker_folder, filename)
                cv2.imwrite(output_path, roi)

        # Display the annotated frame
        cv2.imshow("Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 177.1ms
# Speed: 2.0ms preprocess, 177.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 2 mouths, 126.9ms
# Speed: 2.0ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 2 mouths, 109.3ms
# Speed: 1.7ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 4 faces, 3 mouths, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 4 faces, 4 mouths, 111.6ms
# Speed: 2.9ms preprocess, 111.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 105.9ms
# Speed: 2.9ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 4 faces, 4 mouths, 122.4ms
# Speed: 2.0ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 6 eyes, 4 faces, 4 mouths, 119.6ms
# Speed: 1.0ms preprocess, 119.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 112.7ms
# Speed: 2.9ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 102.5ms
# Speed: 1.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 103.0ms
# Speed: 0.9ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 108.5ms
# Speed: 2.0ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 112.9ms
# Speed: 2.0ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 116.6ms
# Speed: 1.9ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 113.2ms
# Speed: 0.9ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 107.0ms
# Speed: 1.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 134.3ms
# Speed: 2.1ms preprocess, 134.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 4 mouths, 148.1ms
# Speed: 1.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 139.8ms
# Speed: 2.1ms preprocess, 139.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 150.8ms
# Speed: 2.0ms preprocess, 150.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 116.2ms
# Speed: 3.1ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 120.3ms
# Speed: 1.0ms preprocess, 120.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 107.6ms
# Speed: 1.0ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 109.6ms
# Speed: 2.0ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 106.2ms
# Speed: 2.0ms preprocess, 106.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 109.3ms
# Speed: 2.0ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 117.1ms
# Speed: 1.9ms preprocess, 117.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 97.7ms
# Speed: 1.9ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 106.4ms
# Speed: 2.1ms preprocess, 106.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 102.5ms
# Speed: 2.1ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 117.4ms
# Speed: 2.1ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 105.2ms
# Speed: 2.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 105.7ms
# Speed: 2.0ms preprocess, 105.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 101.9ms
# Speed: 1.9ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 117.4ms
# Speed: 2.9ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 112.7ms
# Speed: 2.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 113.2ms
# Speed: 1.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 122.0ms
# Speed: 2.1ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 101.3ms
# Speed: 1.9ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 110.9ms
# Speed: 2.1ms preprocess, 110.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 136.3ms
# Speed: 2.0ms preprocess, 136.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 145.5ms
# Speed: 2.1ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 144.4ms
# Speed: 2.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 139.4ms
# Speed: 1.9ms preprocess, 139.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 101.8ms
# Speed: 1.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 111.3ms
# Speed: 2.1ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 4 faces, 4 mouths, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 4 mouths, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 4 faces, 4 mouths, 101.2ms
# Speed: 1.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 102.6ms
# Speed: 1.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 102.2ms
# Speed: 2.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 97.8ms
# Speed: 1.0ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 102.9ms
# Speed: 1.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 105.7ms
# Speed: 2.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 100.0ms
# Speed: 2.9ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 115.5ms
# Speed: 1.0ms preprocess, 115.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 105.9ms
# Speed: 1.1ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 102.0ms
# Speed: 1.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 101.2ms
# Speed: 0.9ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 95.7ms
# Speed: 2.0ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 106.2ms
# Speed: 2.1ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 105.0ms
# Speed: 1.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 97.3ms
# Speed: 2.0ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 105.6ms
# Speed: 1.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 100.7ms
# Speed: 1.9ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 111.2ms
# Speed: 2.0ms preprocess, 111.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 110.5ms
# Speed: 2.0ms preprocess, 110.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 100.8ms
# Speed: 1.0ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 105.3ms
# Speed: 1.9ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 130.7ms
# Speed: 1.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 147.3ms
# Speed: 2.0ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 132.0ms
# Speed: 2.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 131.0ms
# Speed: 2.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 116.8ms
# Speed: 2.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 99.8ms
# Speed: 1.0ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 112.6ms
# Speed: 2.1ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 105.6ms
# Speed: 2.1ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 111.0ms
# Speed: 1.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 98.2ms
# Speed: 1.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 114.0ms
# Speed: 1.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 117.8ms
# Speed: 1.0ms preprocess, 117.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 103.6ms
# Speed: 2.0ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 113.0ms
# Speed: 1.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 103.5ms
# Speed: 2.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 107.0ms
# Speed: 1.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 100.0ms
# Speed: 1.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 105.5ms
# Speed: 1.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 104.1ms
# Speed: 2.0ms preprocess, 104.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 108.0ms
# Speed: 1.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 102.5ms
# Speed: 1.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 101.0ms
# Speed: 1.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 118.7ms
# Speed: 1.0ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 106.9ms
# Speed: 1.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 115.2ms
# Speed: 2.0ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 104.9ms
# Speed: 1.0ms preprocess, 104.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 101.8ms
# Speed: 1.9ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 110.9ms
# Speed: 2.0ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 121.5ms
# Speed: 2.0ms preprocess, 121.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 140.7ms
# Speed: 1.0ms preprocess, 140.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 132.9ms
# Speed: 2.0ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 98.6ms
# Speed: 2.0ms preprocess, 98.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 132.4ms
# Speed: 2.0ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 115.2ms
# Speed: 1.0ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 113.2ms
# Speed: 1.9ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 110.1ms
# Speed: 1.0ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 107.1ms
# Speed: 1.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 102.9ms
# Speed: 1.0ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 106.6ms
# Speed: 2.0ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 102.9ms
# Speed: 1.0ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 99.0ms
# Speed: 1.0ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 119.0ms
# Speed: 1.9ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 99.3ms
# Speed: 2.0ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 97.8ms
# Speed: 2.0ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 110.8ms
# Speed: 1.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 116.9ms
# Speed: 2.0ms preprocess, 116.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 98.8ms
# Speed: 2.0ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 4 mouths, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 103.4ms
# Speed: 2.1ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 101.7ms
# Speed: 1.0ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 102.4ms
# Speed: 2.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 5 eyes, 3 faces, 4 mouths, 117.2ms
# Speed: 1.0ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 4 mouths, 107.6ms
# Speed: 2.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 103.3ms
# Speed: 2.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 102.8ms
# Speed: 1.9ms preprocess, 102.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 104.1ms
# Speed: 2.0ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 2 faces, 3 mouths, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 3 eyes, 3 faces, 3 mouths, 105.4ms
# Speed: 1.0ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 115.5ms
# Speed: 2.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 110.3ms
# Speed: 1.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 107.2ms
# Speed: 1.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 105.6ms
# Speed: 1.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 103.9ms
# Speed: 2.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 142.0ms
# Speed: 2.0ms preprocess, 142.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 145.1ms
# Speed: 2.0ms preprocess, 145.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 148.3ms
# Speed: 2.1ms preprocess, 148.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 137.8ms
# Speed: 2.0ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 102.7ms
# Speed: 2.0ms preprocess, 102.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 113.9ms
# Speed: 2.2ms preprocess, 113.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 106.3ms
# Speed: 3.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 114.6ms
# Speed: 2.1ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 106.0ms
# Speed: 1.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 114.0ms
# Speed: 1.1ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 110.0ms
# Speed: 2.1ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 105.0ms
# Speed: 1.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 116.0ms
# Speed: 1.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 119.0ms
# Speed: 1.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 105.0ms
# Speed: 1.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 102.0ms
# Speed: 1.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 110.1ms
# Speed: 1.6ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 96.7ms
# Speed: 1.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 107.9ms
# Speed: 2.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 103.3ms
# Speed: 2.1ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 99.1ms
# Speed: 1.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 106.2ms
# Speed: 2.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 111.8ms
# Speed: 2.1ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 107.9ms
# Speed: 1.0ms preprocess, 107.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 108.0ms
# Speed: 1.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 133.0ms
# Speed: 2.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 112.6ms
# Speed: 1.0ms preprocess, 112.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 111.6ms
# Speed: 2.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.2ms
# Speed: 1.9ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 139.5ms
# Speed: 2.4ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 132.0ms
# Speed: 2.0ms preprocess, 132.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 140.0ms
# Speed: 2.0ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 149.3ms
# Speed: 2.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 106.4ms
# Speed: 1.0ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 107.2ms
# Speed: 1.9ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 106.5ms
# Speed: 1.0ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 111.8ms
# Speed: 1.0ms preprocess, 111.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 3 mouths, 145.9ms
# Speed: 1.0ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 112.9ms
# Speed: 2.0ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 117.7ms
# Speed: 2.0ms preprocess, 117.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 112.2ms
# Speed: 2.0ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 111.0ms
# Speed: 1.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 114.4ms
# Speed: 3.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 124.9ms
# Speed: 2.1ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 104.6ms
# Speed: 2.0ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 110.9ms
# Speed: 1.0ms preprocess, 110.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 109.6ms
# Speed: 1.0ms preprocess, 109.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 107.9ms
# Speed: 2.0ms preprocess, 107.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 114.0ms
# Speed: 1.0ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 112.6ms
# Speed: 1.0ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 4 faces, 4 mouths, 108.8ms
# Speed: 2.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 4 faces, 4 mouths, 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 115.1ms
# Speed: 1.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 124.7ms
# Speed: 2.0ms preprocess, 124.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 112.3ms
# Speed: 1.9ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 107.5ms
# Speed: 1.0ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 112.7ms
# Speed: 2.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 115.9ms
# Speed: 2.0ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 117.4ms
# Speed: 1.0ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 3 faces, 3 mouths, 108.8ms
# Speed: 2.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 115.9ms
# Speed: 1.0ms preprocess, 115.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 253.8ms
# Speed: 2.0ms preprocess, 253.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 283.6ms
# Speed: 7.2ms preprocess, 283.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 4 mouths, 127.1ms
# Speed: 2.0ms preprocess, 127.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 4 mouths, 143.6ms
# Speed: 2.0ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 4 mouths, 156.2ms
# Speed: 1.9ms preprocess, 156.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 4 mouths, 154.4ms
# Speed: 2.0ms preprocess, 154.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 130.1ms
# Speed: 1.0ms preprocess, 130.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 124.1ms
# Speed: 1.0ms preprocess, 124.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 132.5ms
# Speed: 2.0ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 133.4ms
# Speed: 2.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 128.1ms
# Speed: 2.0ms preprocess, 128.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 3 mouths, 116.2ms
# Speed: 2.0ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 3 mouths, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 3 mouths, 116.4ms
# Speed: 1.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 4 mouths, 120.8ms
# Speed: 2.4ms preprocess, 120.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 118.9ms
# Speed: 2.1ms preprocess, 118.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 115.1ms
# Speed: 3.0ms preprocess, 115.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 4 mouths, 114.0ms
# Speed: 2.2ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 130.4ms
# Speed: 1.9ms preprocess, 130.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 114.0ms
# Speed: 2.2ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 114.6ms
# Speed: 2.0ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 123.3ms
# Speed: 2.0ms preprocess, 123.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 124.0ms
# Speed: 3.0ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 2 mouths, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 2 mouths, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 2 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 2 mouths, 114.9ms
# Speed: 1.0ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 2 mouths, 122.7ms
# Speed: 2.0ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 112.0ms
# Speed: 1.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 111.8ms
# Speed: 2.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 113.2ms
# Speed: 2.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 110.9ms
# Speed: 1.9ms preprocess, 110.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 118.9ms
# Speed: 2.0ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 122.9ms
# Speed: 2.2ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 124.6ms
# Speed: 2.0ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 1 mouth, 144.3ms
# Speed: 1.9ms preprocess, 144.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 146.9ms
# Speed: 2.0ms preprocess, 146.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 128.0ms
# Speed: 2.0ms preprocess, 128.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 122.7ms
# Speed: 0.8ms preprocess, 122.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 112.7ms
# Speed: 2.0ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 106.8ms
# Speed: 2.0ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 112.5ms
# Speed: 1.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 113.9ms
# Speed: 1.0ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 120.6ms
# Speed: 1.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 4 mouths, 113.0ms
# Speed: 1.0ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 4 mouths, 107.5ms
# Speed: 2.0ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 110.6ms
# Speed: 1.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 121.0ms
# Speed: 0.9ms preprocess, 121.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 107.9ms
# Speed: 2.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 101.8ms
# Speed: 1.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 123.2ms
# Speed: 2.0ms preprocess, 123.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 128.0ms
# Speed: 2.0ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 117.4ms
# Speed: 1.0ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 105.3ms
# Speed: 1.0ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 107.3ms
# Speed: 2.1ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 117.1ms
# Speed: 3.1ms preprocess, 117.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 117.0ms
# Speed: 1.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 116.5ms
# Speed: 2.0ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 119.4ms
# Speed: 0.9ms preprocess, 119.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 105.8ms
# Speed: 2.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 114.4ms
# Speed: 2.1ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 3 mouths, 125.1ms
# Speed: 2.2ms preprocess, 125.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 102.7ms
# Speed: 1.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 130.5ms
# Speed: 1.0ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 154.9ms
# Speed: 2.0ms preprocess, 154.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 148.2ms
# Speed: 1.0ms preprocess, 148.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 119.2ms
# Speed: 2.0ms preprocess, 119.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 118.0ms
# Speed: 1.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 108.0ms
# Speed: 1.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 107.6ms
# Speed: 2.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 133.0ms
# Speed: 2.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.6ms
# Speed: 2.6ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 119.8ms
# Speed: 2.0ms preprocess, 119.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 112.7ms
# Speed: 1.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.3ms
# Speed: 1.9ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 125.0ms
# Speed: 0.9ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 105.8ms
# Speed: 1.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 119.3ms
# Speed: 1.1ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 4 mouths, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 4 mouths, 105.4ms
# Speed: 1.9ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 4 mouths, 100.0ms
# Speed: 2.2ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 119.2ms
# Speed: 2.0ms preprocess, 119.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os

folder_path = 'tracked_info'

# Get a list of all subfolders in the folder
all_folders = [f.path for f in os.scandir(folder_path) if f.is_dir()]

# Find the most recently modified folder
most_recent_folder = max(all_folders, key=os.path.getmtime)

# Extract the name of the most recently modified folder
most_recent_folder_name = os.path.basename(most_recent_folder)

# Count the number of subfolders in the most recently modified folder
number_of_classes = len([f for f in os.scandir(most_recent_folder) if f.is_dir()])

# Now you can use the variable `most_recent_folder` for the path,
# `most_recent_folder_name` for the name, and `number_of_folders` for the count of subfolders.
print("Most recently modified folder path:", most_recent_folder)
print("Most recently modified folder name:", most_recent_folder_name)
print("Number of folders inside:", number_of_classes)
# Out:
# Most recently modified folder path: C:\Users\soumy\tracked_info\20231230_125852
# Most recently modified folder name: 20231230_125852
# Number of folders inside: 16

# %%
import os
import shutil
import random

folder_path = 'tracked_info'

# Get a list of all subfolders in the folder
all_folders = [f.path for f in os.scandir(folder_path) if f.is_dir()]

# Find the most recently modified folder
most_recent_folder = max(all_folders, key=os.path.getmtime)
most_recent_folder_name = os.path.basename(most_recent_folder)

# Create a new folder in the same directory with the name most_recent_folder_name_test
new_folder_path = os.path.join(os.path.dirname(most_recent_folder), f"{most_recent_folder_name}_test")
os.makedirs(new_folder_path, exist_ok=True)

# Count the number of subfolders in the most recently modified folder
number_of_folders = len([f for f in os.scandir(most_recent_folder) if f.is_dir()])

# Iterate through each subfolder and copy 1/4 of its content to the new folder
for subfolder in os.scandir(most_recent_folder):
    if subfolder.is_dir():
        subfolder_name = os.path.basename(subfolder.path)
        new_subfolder_path = os.path.join(new_folder_path, subfolder_name)
        os.makedirs(new_subfolder_path, exist_ok=True)

        # List all files in the subfolder
        files_in_subfolder = [f.path for f in os.scandir(subfolder.path) if f.is_file()]

        # Randomly select 1/4 of the files
        selected_files = random.sample(files_in_subfolder, k=len(files_in_subfolder) // 4)

        # Copy selected files to the new subfolder
        for file_path in selected_files:
            shutil.copy(file_path, new_subfolder_path)

# Now you have a new folder with the name most_recent_folder_name_test
# containing a subset of files from each subfolder in the most recently modified folder
print(f"Subset of files from each subfolder in {most_recent_folder_name} copied to {new_folder_path}")
# Out:
# Subset of files from each subfolder in 20231230_125852 copied to C:\Users\soumy\tracked_info\20231230_125852_test

# %%
# !nvidia-smi
# Out:
# Sat Dec 30 13:02:33 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.33                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P8               5W / 130W |    425MiB /  8188MiB |     47%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     17488    C+G   ...p-app\YouTube Music Desktop App.exe    N/A      |
# |    0   N/A  N/A     32724    C+G   ...Programs\Microsoft VS Code\Code.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
#from tensorflow.keras.backend import set_session
tf.__version__
input_shape = (256, 256, 3)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
training_set = train_datagen.flow_from_directory(
    most_recent_folder,
    target_size=(256, 256),  # Larger target size
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory(new_folder_path,
                                            target_size = (256, 256),
                                            batch_size = 32,
                                            class_mode = 'categorical')
class_names = list(training_set.class_indices.keys())
for i in range(len(class_names)):
    print(f"Class {i}: {class_names[i]}")
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
#set_session(tf.compat.v1.Session(config=config))
# Create a more complex CNN model
cnn = tf.keras.models.Sequential()

# Convolutional layer 1
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=input_shape))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Convolutional layer 2
cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Convolutional layer 3
cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Convolutional layer 4
cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Flatten layer
cnn.add(tf.keras.layers.Flatten())

# Fully connected layer 1
cnn.add(tf.keras.layers.Dense(units=1024, activation='relu'))

# Fully connected layer 2
cnn.add(tf.keras.layers.Dense(units=512, activation='relu'))

# Output layer
cnn.add(tf.keras.layers.Dense(units=number_of_classes, activation='softmax'))

# Compile the model
cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
cnn.summary()
#cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Found 549 images belonging to 16 classes.
# Found 129 images belonging to 16 classes.
# Class 0: tracker_1
# Class 1: tracker_10
# Class 2: tracker_2
# Class 3: tracker_26
# Class 4: tracker_27
# Class 5: tracker_28
# Class 6: tracker_3
# Class 7: tracker_33
# Class 8: tracker_4
# Class 9: tracker_42
# Class 10: tracker_43
# Class 11: tracker_5
# Class 12: tracker_56
# Class 13: tracker_61
# Class 14: tracker_62
# Class 15: tracker_63
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_7 (MaxPoolin  (None, 127, 127, 64)      0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 62, 62, 128)       0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 60, 60, 256)       295168
#
#  max_pooling2d_9 (MaxPoolin  (None, 30, 30, 256)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  max_pooling2d_10 (MaxPooli  (None, 14, 14, 512)       0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_6 (Dense)             (None, 1024)              102761472
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dense_8 (Dense)             (None, 16)                8208
#
# =================================================================
# Total params: 104845456 (399.95 MB)
# Trainable params: 104845456 (399.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 18/18 [==============================] - 29s 2s/step - loss: 2.8645 - accuracy: 0.1002 - val_loss: 2.4679 - val_accuracy: 0.2093
# Epoch 2/25
# 18/18 [==============================] - 27s 1s/step - loss: 2.1896 - accuracy: 0.3042 - val_loss: 1.2883 - val_accuracy: 0.7054
# Epoch 3/25
# 18/18 [==============================] - 27s 2s/step - loss: 1.1442 - accuracy: 0.6576 - val_loss: 0.2781 - val_accuracy: 0.9457
# Epoch 4/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.4245 - accuracy: 0.8525 - val_loss: 0.1103 - val_accuracy: 0.9690
# Epoch 5/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.2082 - accuracy: 0.9308 - val_loss: 0.0212 - val_accuracy: 0.9922
# Epoch 6/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.1932 - accuracy: 0.9435 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 7/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.1152 - accuracy: 0.9636 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 8/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0749 - accuracy: 0.9781 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 9/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0343 - accuracy: 0.9872 - val_loss: 0.0778 - val_accuracy: 0.9767
# Epoch 10/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.1354 - accuracy: 0.9636 - val_loss: 0.0115 - val_accuracy: 0.9922
# Epoch 11/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0922 - accuracy: 0.9745 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 12/25
# 18/18 [==============================] - 26s 1s/step - loss: 0.0234 - accuracy: 0.9927 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 13/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7669e-04 - val_accuracy: 1.0000
# Epoch 14/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3408e-04 - val_accuracy: 1.0000
# Epoch 15/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 1.5735e-04 - val_accuracy: 1.0000
# Epoch 16/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0266 - accuracy: 0.9964 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 17/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 1.7216e-04 - val_accuracy: 1.0000
# Epoch 18/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0464 - accuracy: 0.9872 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 19/25
# 18/18 [==============================] - 27s 2s/step - loss: 0.0967 - accuracy: 0.9654 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 20/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0695 - accuracy: 0.9836 - val_loss: 0.1196 - val_accuracy: 0.9690
# Epoch 21/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0238 - accuracy: 0.9909 - val_loss: 9.2856e-04 - val_accuracy: 1.0000
# Epoch 22/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0202 - accuracy: 0.9945 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 23/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0403 - accuracy: 0.9945 - val_loss: 9.2135e-05 - val_accuracy: 1.0000
# Epoch 24/25
# 18/18 [==============================] - 27s 2s/step - loss: 0.0382 - accuracy: 0.9872 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 25/25
# 18/18 [==============================] - 28s 2s/step - loss: 0.0493 - accuracy: 0.9891 - val_loss: 0.0161 - val_accuracy: 1.0000

# %%
cnn.save('simple_model.h5')
# Out:
# c:\Users\soumy\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Check if GPU is available for TensorFlow operations
print("GPU Available: ", tf.test.is_gpu_available())
# Out:
# Num GPUs Available:  0
# GPU Available:  False

# %%
import tensorflow as tf

# Explicitly set GPU memory growth to True
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)

# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO
import os
from datetime import datetime
import uuid

# Load the YOLOv8 model
model = YOLO('best.pt')

# Open the video file
#video_path = "C:\\Users\\soumy\\Downloads\\videoplayback.mp4"
video_path = "pexels-drvivasayam-youtube-channel-6733515 (1080p).mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history and image count for each track ID
track_history = defaultdict(lambda: {'history': [], 'img_count': 0})

# Create a folder for saving tracked information with current date and time
output_folder_root = "valid_info"
output_folder_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
os.makedirs(output_folder_root, exist_ok=True)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, conf=0.3, iou=0.5, tracker="bytetrack.yaml")
        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            track_ids = results[0].boxes.id.cpu().numpy().astype(int)
            confidences = results[0].boxes.conf.cpu().numpy().astype(int)
            class_names = results[0].names
        # Get the boxes and track IDs
        # boxes = results[0].boxes.xywh.cpu()
        # track_ids = results[0].boxes.id.int().cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks and save cropped images with random filenames
        for box, track_id, class_name in zip(boxes, track_ids, class_names):
            x, y, w, h = box
            track_info = track_history[track_id]
            track = track_info['history']
            img_count = track_info['img_count']

            track.append((float(x), float(y)))  # x, y center point

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

            # Crop the region of interest
            roi = frame[y:h, x:w]

            if img_count < 20:
                # Save the cropped image with a random unique filename
                unique_filename = str(uuid.uuid4())[:8]  # Using a portion of a UUID as a unique identifier
                tracker_folder = os.path.join(output_folder_root, output_folder_datetime, f"tracker_{track_id}")
                os.makedirs(tracker_folder, exist_ok=True)
                filename = f"{unique_filename}.jpg"
                output_path = os.path.join(tracker_folder, filename)
                cv2.imwrite(output_path, roi)

                # Update the image count for the current track ID
                track_info['img_count'] += 1

        # Display the annotated frame
        cv2.imshow("Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 161.4ms
# Speed: 7.5ms preprocess, 161.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 2 mouths, 148.9ms
# Speed: 2.0ms preprocess, 148.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 2 mouths, 125.0ms
# Speed: 2.3ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 4 faces, 3 mouths, 124.2ms
# Speed: 1.1ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 4 faces, 4 mouths, 130.9ms
# Speed: 1.0ms preprocess, 130.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 136.2ms
# Speed: 2.0ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 173.2ms
# Speed: 2.0ms preprocess, 173.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 4 faces, 4 mouths, 140.4ms
# Speed: 2.9ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 6 eyes, 4 faces, 4 mouths, 123.7ms
# Speed: 2.0ms preprocess, 123.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 142.4ms
# Speed: 1.9ms preprocess, 142.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 3 faces, 3 mouths, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 126.9ms
# Speed: 1.0ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 105.7ms
# Speed: 1.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 107.3ms
# Speed: 2.0ms preprocess, 107.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 4 mouths, 151.5ms
# Speed: 1.0ms preprocess, 151.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 109.1ms
# Speed: 2.4ms preprocess, 109.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 115.7ms
# Speed: 2.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 114.1ms
# Speed: 1.0ms preprocess, 114.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 108.4ms
# Speed: 2.0ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 104.6ms
# Speed: 1.0ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 111.6ms
# Speed: 1.9ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 106.2ms
# Speed: 1.5ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 116.2ms
# Speed: 3.1ms preprocess, 116.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 107.4ms
# Speed: 1.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 114.2ms
# Speed: 1.0ms preprocess, 114.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 114.6ms
# Speed: 2.0ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 112.7ms
# Speed: 2.1ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 107.2ms
# Speed: 2.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 102.7ms
# Speed: 1.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 106.4ms
# Speed: 2.0ms preprocess, 106.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 107.0ms
# Speed: 1.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 111.9ms
# Speed: 2.0ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 3 faces, 3 mouths, 109.0ms
# Speed: 1.8ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 109.0ms
# Speed: 3.1ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 113.0ms
# Speed: 2.1ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 141.7ms
# Speed: 2.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 144.0ms
# Speed: 3.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 140.9ms
# Speed: 2.1ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 144.4ms
# Speed: 3.1ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 117.7ms
# Speed: 1.0ms preprocess, 117.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 115.7ms
# Speed: 2.1ms preprocess, 115.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 108.9ms
# Speed: 2.1ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 129.7ms
# Speed: 1.9ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 105.0ms
# Speed: 1.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 112.0ms
# Speed: 1.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 103.9ms
# Speed: 1.0ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 101.0ms
# Speed: 1.0ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 106.6ms
# Speed: 2.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 4 faces, 4 mouths, 128.5ms
# Speed: 2.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 4 mouths, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 115.3ms
# Speed: 2.0ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 104.4ms
# Speed: 1.0ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 4 faces, 4 mouths, 116.9ms
# Speed: 0.0ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 145.4ms
# Speed: 1.0ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 113.0ms
# Speed: 1.9ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 119.6ms
# Speed: 3.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 109.8ms
# Speed: 2.0ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 111.3ms
# Speed: 2.0ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 113.0ms
# Speed: 1.9ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 124.9ms
# Speed: 1.0ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 109.9ms
# Speed: 1.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 120.4ms
# Speed: 1.0ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 101.2ms
# Speed: 2.7ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 104.6ms
# Speed: 1.0ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 113.5ms
# Speed: 2.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 126.0ms
# Speed: 1.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 137.2ms
# Speed: 2.0ms preprocess, 137.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 141.4ms
# Speed: 3.0ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 168.8ms
# Speed: 0.9ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 131.9ms
# Speed: 1.0ms preprocess, 131.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 113.0ms
# Speed: 0.9ms preprocess, 113.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 112.4ms
# Speed: 1.0ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.9ms
# Speed: 3.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 125.1ms
# Speed: 2.0ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 104.1ms
# Speed: 1.0ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 112.4ms
# Speed: 1.0ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 130.7ms
# Speed: 1.9ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 116.4ms
# Speed: 1.6ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 118.1ms
# Speed: 1.0ms preprocess, 118.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 107.9ms
# Speed: 1.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 106.1ms
# Speed: 1.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 133.0ms
# Speed: 1.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 121.9ms
# Speed: 2.1ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 111.0ms
# Speed: 1.8ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 112.6ms
# Speed: 2.0ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 129.1ms
# Speed: 2.0ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 132.0ms
# Speed: 2.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 107.5ms
# Speed: 2.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 113.3ms
# Speed: 3.0ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 114.1ms
# Speed: 1.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 103.8ms
# Speed: 0.9ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 125.9ms
# Speed: 2.0ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 110.9ms
# Speed: 2.0ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 126.9ms
# Speed: 2.1ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 117.0ms
# Speed: 1.0ms preprocess, 117.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 106.1ms
# Speed: 2.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 129.8ms
# Speed: 1.0ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 117.8ms
# Speed: 1.1ms preprocess, 117.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 135.1ms
# Speed: 1.0ms preprocess, 135.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 138.4ms
# Speed: 1.7ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 154.6ms
# Speed: 2.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 149.3ms
# Speed: 2.0ms preprocess, 149.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 112.5ms
# Speed: 2.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 110.9ms
# Speed: 3.0ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 138.8ms
# Speed: 2.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 116.3ms
# Speed: 1.0ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 109.6ms
# Speed: 2.0ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 107.1ms
# Speed: 1.0ms preprocess, 107.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 108.6ms
# Speed: 0.9ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 120.9ms
# Speed: 2.1ms preprocess, 120.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 126.5ms
# Speed: 3.0ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 124.9ms
# Speed: 1.0ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 105.3ms
# Speed: 1.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 118.1ms
# Speed: 1.0ms preprocess, 118.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 104.4ms
# Speed: 2.0ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 127.0ms
# Speed: 1.0ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 115.0ms
# Speed: 2.1ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 122.7ms
# Speed: 2.2ms preprocess, 122.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 104.5ms
# Speed: 1.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 118.9ms
# Speed: 1.0ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 104.8ms
# Speed: 1.2ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 125.5ms
# Speed: 2.1ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 107.9ms
# Speed: 2.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 109.3ms
# Speed: 3.0ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 103.4ms
# Speed: 2.0ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 109.6ms
# Speed: 0.9ms preprocess, 109.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 107.2ms
# Speed: 1.9ms preprocess, 107.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 114.2ms
# Speed: 2.1ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 3 mouths, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 3 mouths, 109.5ms
# Speed: 1.9ms preprocess, 109.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 133.8ms
# Speed: 1.9ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 142.0ms
# Speed: 2.0ms preprocess, 142.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 153.8ms
# Speed: 1.0ms preprocess, 153.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 5 eyes, 3 faces, 4 mouths, 121.9ms
# Speed: 1.0ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 124.5ms
# Speed: 3.4ms preprocess, 124.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 122.5ms
# Speed: 2.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 4 eyes, 3 faces, 4 mouths, 98.8ms
# Speed: 1.0ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 ears, 5 eyes, 3 faces, 4 mouths, 110.6ms
# Speed: 2.0ms preprocess, 110.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 3 faces, 4 mouths, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 114.9ms
# Speed: 2.0ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 113.3ms
# Speed: 2.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 110.6ms
# Speed: 2.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 2 faces, 3 mouths, 121.5ms
# Speed: 1.0ms preprocess, 121.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 3 eyes, 3 faces, 3 mouths, 114.1ms
# Speed: 1.9ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 113.4ms
# Speed: 1.0ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 112.9ms
# Speed: 2.0ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 107.7ms
# Speed: 1.0ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 125.7ms
# Speed: 1.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 122.8ms
# Speed: 1.0ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 110.7ms
# Speed: 1.9ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 107.3ms
# Speed: 2.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 126.9ms
# Speed: 2.0ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 113.6ms
# Speed: 3.0ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 111.8ms
# Speed: 1.0ms preprocess, 111.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 122.8ms
# Speed: 1.0ms preprocess, 122.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 111.3ms
# Speed: 1.0ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 106.0ms
# Speed: 1.9ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 118.3ms
# Speed: 2.1ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 129.3ms
# Speed: 1.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 113.8ms
# Speed: 1.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 143.2ms
# Speed: 3.0ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 108.4ms
# Speed: 2.0ms preprocess, 108.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 7 eyes, 4 faces, 4 mouths, 129.0ms
# Speed: 1.0ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 129.1ms
# Speed: 1.0ms preprocess, 129.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 105.3ms
# Speed: 1.8ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 107.9ms
# Speed: 2.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 137.1ms
# Speed: 2.1ms preprocess, 137.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 130.6ms
# Speed: 2.4ms preprocess, 130.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 163.6ms
# Speed: 1.0ms preprocess, 163.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 165.3ms
# Speed: 1.9ms preprocess, 165.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 118.8ms
# Speed: 3.0ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 111.5ms
# Speed: 2.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 6 eyes, 4 faces, 4 mouths, 126.0ms
# Speed: 1.0ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 109.1ms
# Speed: 2.0ms preprocess, 109.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 6 eyes, 4 faces, 4 mouths, 105.5ms
# Speed: 1.9ms preprocess, 105.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 110.4ms
# Speed: 2.0ms preprocess, 110.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 105.1ms
# Speed: 2.2ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 115.6ms
# Speed: 1.9ms preprocess, 115.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 104.0ms
# Speed: 2.1ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 123.9ms
# Speed: 2.1ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 3 mouths, 117.0ms
# Speed: 1.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 117.3ms
# Speed: 1.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 3 mouths, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 118.1ms
# Speed: 2.0ms preprocess, 118.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 120.6ms
# Speed: 1.9ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 102.9ms
# Speed: 2.3ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 109.9ms
# Speed: 2.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 123.0ms
# Speed: 2.0ms preprocess, 123.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 108.0ms
# Speed: 1.6ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 161.0ms
# Speed: 1.0ms preprocess, 161.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 4 mouths, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 4 faces, 4 mouths, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 117.6ms
# Speed: 2.0ms preprocess, 117.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 4 faces, 4 mouths, 107.2ms
# Speed: 1.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 ears, 4 eyes, 4 faces, 4 mouths, 113.2ms
# Speed: 2.1ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 130.7ms
# Speed: 1.9ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 148.9ms
# Speed: 1.0ms preprocess, 148.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 148.9ms
# Speed: 3.0ms preprocess, 148.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 148.6ms
# Speed: 2.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 125.4ms
# Speed: 1.9ms preprocess, 125.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 129.4ms
# Speed: 1.9ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 4 mouths, 133.1ms
# Speed: 2.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 3 faces, 3 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 126.0ms
# Speed: 2.1ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 121.5ms
# Speed: 2.0ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 3 mouths, 110.8ms
# Speed: 2.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 4 mouths, 121.5ms
# Speed: 1.7ms preprocess, 121.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 2 eyes, 4 faces, 4 mouths, 108.0ms
# Speed: 0.9ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 4 mouths, 112.3ms
# Speed: 1.0ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 4 mouths, 118.5ms
# Speed: 2.0ms preprocess, 118.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 138.0ms
# Speed: 2.0ms preprocess, 138.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 111.5ms
# Speed: 2.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 2 eyes, 3 faces, 3 mouths, 118.4ms
# Speed: 2.0ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 121.0ms
# Speed: 1.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 119.1ms
# Speed: 2.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 116.6ms
# Speed: 2.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 3 mouths, 132.2ms
# Speed: 1.0ms preprocess, 132.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 3 mouths, 126.3ms
# Speed: 2.0ms preprocess, 126.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 3 mouths, 125.6ms
# Speed: 1.0ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 2 faces, 4 mouths, 110.3ms
# Speed: 1.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 114.5ms
# Speed: 2.0ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 4 mouths, 119.0ms
# Speed: 2.1ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 117.3ms
# Speed: 2.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 111.1ms
# Speed: 3.2ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 3 faces, 3 mouths, 109.9ms
# Speed: 2.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 120.1ms
# Speed: 2.0ms preprocess, 120.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 105.4ms
# Speed: 1.0ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 4 mouths, 113.1ms
# Speed: 1.0ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 129.1ms
# Speed: 2.0ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 2 mouths, 117.7ms
# Speed: 2.0ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 2 faces, 2 mouths, 139.9ms
# Speed: 3.0ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 2 mouths, 170.1ms
# Speed: 1.0ms preprocess, 170.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 2 mouths, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 2 mouths, 140.3ms
# Speed: 2.0ms preprocess, 140.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 3 mouths, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 119.1ms
# Speed: 2.9ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 4 eyes, 3 faces, 4 mouths, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 136.3ms
# Speed: 2.1ms preprocess, 136.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 119.1ms
# Speed: 3.1ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 120.0ms
# Speed: 2.3ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 2 mouths, 111.4ms
# Speed: 2.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 1 mouth, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 120.0ms
# Speed: 1.0ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 138.3ms
# Speed: 3.0ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 114.4ms
# Speed: 2.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 111.4ms
# Speed: 2.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 124.3ms
# Speed: 2.0ms preprocess, 124.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 132.1ms
# Speed: 1.0ms preprocess, 132.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 156.8ms
# Speed: 1.1ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 108.0ms
# Speed: 1.9ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 107.9ms
# Speed: 2.1ms preprocess, 107.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 116.5ms
# Speed: 2.0ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 4 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 4 mouths, 111.4ms
# Speed: 2.0ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 116.5ms
# Speed: 2.0ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 121.0ms
# Speed: 1.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 108.0ms
# Speed: 1.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 3 faces, 3 mouths, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 138.9ms
# Speed: 2.0ms preprocess, 138.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 108.5ms
# Speed: 1.9ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 118.0ms
# Speed: 1.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 133.1ms
# Speed: 2.1ms preprocess, 133.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 127.5ms
# Speed: 1.9ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 4 mouths, 109.1ms
# Speed: 2.0ms preprocess, 109.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 135.4ms
# Speed: 2.0ms preprocess, 135.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 4 mouths, 136.5ms
# Speed: 3.0ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 162.6ms
# Speed: 2.0ms preprocess, 162.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 3 faces, 3 mouths, 144.1ms
# Speed: 2.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 118.2ms
# Speed: 2.0ms preprocess, 118.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 3 faces, 3 mouths, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 128.0ms
# Speed: 1.0ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 3 mouths, 124.4ms
# Speed: 1.0ms preprocess, 124.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 5 eyes, 3 faces, 4 mouths, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 3 faces, 4 mouths, 127.4ms
# Speed: 1.1ms preprocess, 127.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 121.2ms
# Speed: 2.0ms preprocess, 121.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 131.4ms
# Speed: 1.9ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 ears, 4 eyes, 4 faces, 4 mouths, 113.3ms
# Speed: 1.0ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 135.3ms
# Speed: 1.9ms preprocess, 135.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 122.0ms
# Speed: 1.9ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 129.0ms
# Speed: 2.0ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 117.0ms
# Speed: 2.1ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 125.2ms
# Speed: 1.0ms preprocess, 125.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 117.9ms
# Speed: 2.2ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 122.0ms
# Speed: 3.0ms preprocess, 122.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 126.4ms
# Speed: 2.0ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 111.2ms
# Speed: 1.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 4 mouths, 108.9ms
# Speed: 1.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 4 mouths, 105.3ms
# Speed: 1.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 4 mouths, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 4 mouths, 111.5ms
# Speed: 1.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 4 mouths, 117.3ms
# Speed: 1.9ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 4 mouths, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 4 eyes, 4 faces, 4 mouths, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 4 mouths, 110.6ms
# Speed: 2.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 3 mouths, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 5 eyes, 4 faces, 3 mouths, 129.3ms
# Speed: 2.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 154.0ms
# Speed: 2.0ms preprocess, 154.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 139.0ms
# Speed: 2.0ms preprocess, 139.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 142.4ms
# Speed: 2.5ms preprocess, 142.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 123.0ms
# Speed: 2.0ms preprocess, 123.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 108.7ms
# Speed: 1.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 5 eyes, 4 faces, 3 mouths, 125.9ms
# Speed: 1.0ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 3 mouths, 120.5ms
# Speed: 1.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 3 mouths, 113.0ms
# Speed: 1.9ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 5 eyes, 4 faces, 3 mouths, 146.2ms
# Speed: 1.0ms preprocess, 146.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 105.8ms
# Speed: 1.0ms preprocess, 105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 119.1ms
# Speed: 1.7ms preprocess, 119.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 4 faces, 3 mouths, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 4 eyes, 4 faces, 3 mouths, 121.9ms
# Speed: 1.0ms preprocess, 121.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 4 eyes, 4 faces, 3 mouths, 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 3 mouths, 123.2ms
# Speed: 1.0ms preprocess, 123.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 3 mouths, 119.8ms
# Speed: 1.0ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 5 eyes, 4 faces, 3 mouths, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 3 mouths, 137.4ms
# Speed: 1.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 3 mouths, 110.4ms
# Speed: 1.0ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 4 faces, 3 mouths, 113.8ms
# Speed: 1.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 ears, 3 eyes, 3 faces, 3 mouths, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 4 mouths, 106.6ms
# Speed: 1.9ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 3 faces, 4 mouths, 105.1ms
# Speed: 1.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 3 faces, 4 mouths, 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ear, 3 eyes, 3 faces, 4 mouths, 119.7ms
# Speed: 2.0ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ears, 3 eyes, 3 faces, 3 mouths, 104.3ms
# Speed: 2.0ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 126.1ms
# Speed: 2.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 ears, 3 eyes, 3 faces, 3 mouths, 107.4ms
# Speed: 1.9ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
loaded_model = load_model('simple_model.h5')

# %%
import os
import tensorflow as tf
from tensorflow.compat.v1.losses import sparse_softmax_cross_entropy
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
from datetime import datetime
# Path to the "valid_info" directory
valid_info_path = 'valid_info'

input_shape = (256, 256, 3)
confidence_threshold = .9
valid_percentage_threshold = 0.7
# Function to get the most recently modified subdirectory
def get_most_recent_subdirectory(directory):
    subdirectories = [os.path.join(directory, d) for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))]
    return max(subdirectories, key=os.path.getmtime)

# Get the most recently modified subdirectory within "valid_info"
most_recent_folder = get_most_recent_subdirectory(valid_info_path)

class_indices = training_set.class_indices
class_names = list(class_indices.keys())

# Loop through folders in the most recently modified subdirectory
for folder_name in os.listdir(most_recent_folder):
    folder_path = os.path.join(most_recent_folder, folder_name)

    # Check if the path is a directory
    if os.path.isdir(folder_path):
        print(f"\nProcessing images in folder: {folder_name}")

        # Initialize counters for valid and total predictions
        valid_count = 0
        total_count = 0

        # Loop through images in the current folder
        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)

            # Load and preprocess the image for prediction
            img = tf.keras.preprocessing.image.load_img(img_path, target_size=(256, 256))
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array /= 255.0  # Normalize the pixel values to be between 0 and 1

            # Make a prediction using the loaded model
            predictions = loaded_model.predict(img_array)

            # Get the predicted class index and confidence
            predicted_class_index = np.argmax(predictions)
            confidence = predictions[0][predicted_class_index]

            # Print "valid" or "invalid" based on the confidence threshold
            result = "valid" if confidence > confidence_threshold else "invalid"

            # Display class name instead of class index
            predicted_class_name = class_names[predicted_class_index]

            print(f"Image: {img_name}, Predicted Class: {predicted_class_name}, Confidence: {confidence:.4f}, Result: {result}")

            # Update counters
            if result == "valid":
                valid_count += 1
            total_count += 1

        # Check if more than 80% of the images are valid in the folder
        valid_percentage = valid_count / total_count
        folder_result = "valid" if valid_percentage > valid_percentage_threshold else "invalid"

        print(f"Folder: {folder_name}, Valid Percentage: {valid_percentage:.2%}, Result: {folder_result}")
# Out:
# Processing images in folder: tracker_1
# 1/1 [==============================] - 0s 39ms/step
# Image: 0af984a8.jpg, Predicted Class: tracker_1, Confidence: 0.9983, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: 25dec763.jpg, Predicted Class: tracker_1, Confidence: 0.9923, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 489487b7.jpg, Predicted Class: tracker_1, Confidence: 0.9995, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 66708dda.jpg, Predicted Class: tracker_1, Confidence: 0.9974, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 66f9ba5c.jpg, Predicted Class: tracker_1, Confidence: 0.9974, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 69d320e2.jpg, Predicted Class: tracker_1, Confidence: 0.9967, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 77d0b771.jpg, Predicted Class: tracker_1, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 7a747448.jpg, Predicted Class: tracker_1, Confidence: 0.9992, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 7fd8d5f9.jpg, Predicted Class: tracker_1, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 80dfa8d7.jpg, Predicted Class: tracker_1, Confidence: 0.9924, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 878be7ed.jpg, Predicted Class: tracker_1, Confidence: 0.9989, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 88d2c06c.jpg, Predicted Class: tracker_1, Confidence: 0.9942, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: a35953c8.jpg, Predicted Class: tracker_1, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: ae0dcbbe.jpg, Predicted Class: tracker_1, Confidence: 0.9939, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: b3188346.jpg, Predicted Class: tracker_1, Confidence: 0.9981, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: bf2bbc12.jpg, Predicted Class: tracker_1, Confidence: 0.9977, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: d627f977.jpg, Predicted Class: tracker_1, Confidence: 0.9970, Result: valid
# 1/1 [==============================] - 0s 44ms/step
# Image: dd27372e.jpg, Predicted Class: tracker_1, Confidence: 0.9960, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: e0329d83.jpg, Predicted Class: tracker_1, Confidence: 0.9997, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e48db0cb.jpg, Predicted Class: tracker_1, Confidence: 0.9784, Result: valid
# Folder: tracker_1, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_10
# 1/1 [==============================] - 0s 39ms/step
# Image: 01ecccb0.jpg, Predicted Class: tracker_10, Confidence: 0.9969, Result: valid
# 1/1 [==============================] - 0s 41ms/step
# Image: 07c324fa.jpg, Predicted Class: tracker_10, Confidence: 0.9896, Result: valid
# 1/1 [==============================] - 0s 43ms/step
# Image: 0b332c83.jpg, Predicted Class: tracker_10, Confidence: 0.9956, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 0d43d4a4.jpg, Predicted Class: tracker_10, Confidence: 0.9962, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 20e1d8de.jpg, Predicted Class: tracker_10, Confidence: 0.9966, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 21a13a34.jpg, Predicted Class: tracker_10, Confidence: 0.9978, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 3006df9c.jpg, Predicted Class: tracker_10, Confidence: 0.9933, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 88752627.jpg, Predicted Class: tracker_10, Confidence: 0.9961, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 89373b94.jpg, Predicted Class: tracker_10, Confidence: 0.9977, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 8fd53952.jpg, Predicted Class: tracker_10, Confidence: 0.9960, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: bfa0143b.jpg, Predicted Class: tracker_10, Confidence: 0.9968, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d667bc07.jpg, Predicted Class: tracker_10, Confidence: 0.9810, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: d978186a.jpg, Predicted Class: tracker_10, Confidence: 0.9965, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: f5086290.jpg, Predicted Class: tracker_10, Confidence: 0.9855, Result: valid
# Folder: tracker_10, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_2
# 1/1 [==============================] - 0s 39ms/step
# Image: 24f5f8a9.jpg, Predicted Class: tracker_2, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 359cf3c7.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 3b4c9026.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 44f36871.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 4a9120fc.jpg, Predicted Class: tracker_2, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 4b092c2e.jpg, Predicted Class: tracker_2, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 4f8dc115.jpg, Predicted Class: tracker_2, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 5cce2daa.jpg, Predicted Class: tracker_2, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 682f884f.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 78d3e4d0.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 8c53712b.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 979afa88.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: a2ffcd2d.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: a6f20583.jpg, Predicted Class: tracker_2, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 48ms/step
# Image: ace4f3f2.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: b8fc07b8.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: be33c357.jpg, Predicted Class: tracker_2, Confidence: 0.9997, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: d7f19fc2.jpg, Predicted Class: tracker_2, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 45ms/step
# Image: e1bccddb.jpg, Predicted Class: tracker_2, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: f82a9e5a.jpg, Predicted Class: tracker_2, Confidence: 1.0000, Result: valid
# Folder: tracker_2, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_26
# 1/1 [==============================] - 0s 36ms/step
# Image: 03223ab0.jpg, Predicted Class: tracker_26, Confidence: 0.9701, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 21e75cf1.jpg, Predicted Class: tracker_26, Confidence: 0.9744, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 34f8f086.jpg, Predicted Class: tracker_26, Confidence: 0.9670, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 3af1381a.jpg, Predicted Class: tracker_26, Confidence: 0.9668, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 4d95e693.jpg, Predicted Class: tracker_26, Confidence: 0.9743, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: b45ad98b.jpg, Predicted Class: tracker_26, Confidence: 0.9689, Result: valid
# Folder: tracker_26, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_27
# 1/1 [==============================] - 0s 39ms/step
# Image: 012d1bf9.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 0a1ddbe9.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 15b6bbd0.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 19f42967.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: 3946742c.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 88886461.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: ade8a82b.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: afae9230.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: b278cf2d.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: b61e41f0.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: ba4f42de.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d5f8409a.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: d6e4553f.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: dbfb0652.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 43ms/step
# Image: e812191e.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: e85d3c5e.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: ea05a2d2.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: ec60ece8.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: f6146eb0.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 46ms/step
# Image: fe48f229.jpg, Predicted Class: tracker_27, Confidence: 1.0000, Result: valid
# Folder: tracker_27, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_28
# 1/1 [==============================] - 0s 42ms/step
# Image: 005b9cfe.jpg, Predicted Class: tracker_28, Confidence: 0.8154, Result: invalid
# 1/1 [==============================] - 0s 37ms/step
# Image: 16435fb4.jpg, Predicted Class: tracker_28, Confidence: 0.9338, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 4a81ad39.jpg, Predicted Class: tracker_28, Confidence: 0.9077, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 60db7922.jpg, Predicted Class: tracker_28, Confidence: 0.9960, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 70a2ed29.jpg, Predicted Class: tracker_28, Confidence: 0.8873, Result: invalid
# 1/1 [==============================] - 0s 39ms/step
# Image: 77b6ed0d.jpg, Predicted Class: tracker_28, Confidence: 0.9603, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 88cb0692.jpg, Predicted Class: tracker_28, Confidence: 0.8985, Result: invalid
# 1/1 [==============================] - 0s 37ms/step
# Image: 96414133.jpg, Predicted Class: tracker_28, Confidence: 0.9582, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 9e72150e.jpg, Predicted Class: tracker_28, Confidence: 0.9936, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: a62cb5f6.jpg, Predicted Class: tracker_28, Confidence: 0.9143, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: ae116fe1.jpg, Predicted Class: tracker_28, Confidence: 0.8419, Result: invalid
# 1/1 [==============================] - 0s 39ms/step
# Image: b1e5443b.jpg, Predicted Class: tracker_28, Confidence: 0.9520, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: b248d566.jpg, Predicted Class: tracker_28, Confidence: 0.8577, Result: invalid
# 1/1 [==============================] - 0s 39ms/step
# Image: bb794a9b.jpg, Predicted Class: tracker_28, Confidence: 0.9473, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: bd71ecc4.jpg, Predicted Class: tracker_28, Confidence: 0.9082, Result: valid
# 1/1 [==============================] - 0s 44ms/step
# Image: c2584392.jpg, Predicted Class: tracker_28, Confidence: 0.9168, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: d5f34142.jpg, Predicted Class: tracker_28, Confidence: 0.9426, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e4e3023a.jpg, Predicted Class: tracker_28, Confidence: 0.9347, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: ebfd57e1.jpg, Predicted Class: tracker_28, Confidence: 0.8337, Result: invalid
# 1/1 [==============================] - 0s 38ms/step
# Image: f0c5263b.jpg, Predicted Class: tracker_28, Confidence: 0.9793, Result: valid
# Folder: tracker_28, Valid Percentage: 70.00%, Result: invalid
#
# Processing images in folder: tracker_3
# 1/1 [==============================] - 0s 37ms/step
# Image: 0878139c.jpg, Predicted Class: tracker_3, Confidence: 0.9553, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 08f38050.jpg, Predicted Class: tracker_3, Confidence: 0.9980, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 0ee15d42.jpg, Predicted Class: tracker_3, Confidence: 0.9921, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 1355f034.jpg, Predicted Class: tracker_3, Confidence: 0.9969, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 252196aa.jpg, Predicted Class: tracker_3, Confidence: 0.9770, Result: valid
# 1/1 [==============================] - 0s 45ms/step
# Image: 34c92739.jpg, Predicted Class: tracker_3, Confidence: 0.9774, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 51f0f2dd.jpg, Predicted Class: tracker_3, Confidence: 0.9417, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 688b9e64.jpg, Predicted Class: tracker_3, Confidence: 0.9833, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 6ab32d9c.jpg, Predicted Class: tracker_3, Confidence: 0.9942, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 8803e893.jpg, Predicted Class: tracker_3, Confidence: 0.9852, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 91711621.jpg, Predicted Class: tracker_3, Confidence: 0.9920, Result: valid
# 1/1 [==============================] - 0s 44ms/step
# Image: 9262982a.jpg, Predicted Class: tracker_3, Confidence: 0.8896, Result: invalid
# 1/1 [==============================] - 0s 36ms/step
# Image: aa6ed1a2.jpg, Predicted Class: tracker_3, Confidence: 0.9934, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: b2c4d9be.jpg, Predicted Class: tracker_3, Confidence: 0.9600, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: b3952961.jpg, Predicted Class: tracker_3, Confidence: 0.9646, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: b88b3380.jpg, Predicted Class: tracker_3, Confidence: 0.9982, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: d07d1977.jpg, Predicted Class: tracker_3, Confidence: 0.9980, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d7a19e2e.jpg, Predicted Class: tracker_3, Confidence: 0.9079, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: e9e9be24.jpg, Predicted Class: tracker_3, Confidence: 0.9981, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: eb017c38.jpg, Predicted Class: tracker_3, Confidence: 0.9971, Result: valid
# Folder: tracker_3, Valid Percentage: 95.00%, Result: valid
#
# Processing images in folder: tracker_33
# 1/1 [==============================] - 0s 37ms/step
# Image: 100530a1.jpg, Predicted Class: tracker_33, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 19d5da11.jpg, Predicted Class: tracker_33, Confidence: 0.9979, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 28be459f.jpg, Predicted Class: tracker_33, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 2cb1a924.jpg, Predicted Class: tracker_33, Confidence: 0.9971, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 3b9d8be4.jpg, Predicted Class: tracker_33, Confidence: 0.9973, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 40a7ae5e.jpg, Predicted Class: tracker_33, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 522e373e.jpg, Predicted Class: tracker_33, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 44ms/step
# Image: 6e18d9e5.jpg, Predicted Class: tracker_33, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 9590db63.jpg, Predicted Class: tracker_33, Confidence: 0.9979, Result: valid
# 1/1 [==============================] - 0s 43ms/step
# Image: a6eef0bb.jpg, Predicted Class: tracker_33, Confidence: 0.9964, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: a7da85f2.jpg, Predicted Class: tracker_33, Confidence: 0.9993, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: aa4c2ab1.jpg, Predicted Class: tracker_33, Confidence: 0.9925, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: b065b557.jpg, Predicted Class: tracker_33, Confidence: 0.9999, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: be941b77.jpg, Predicted Class: tracker_33, Confidence: 0.9967, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: c9cd2c89.jpg, Predicted Class: tracker_33, Confidence: 0.9949, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: cd56764c.jpg, Predicted Class: tracker_33, Confidence: 0.9967, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: cf6183a7.jpg, Predicted Class: tracker_33, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: d3f8335e.jpg, Predicted Class: tracker_33, Confidence: 0.9915, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: ea1a606c.jpg, Predicted Class: tracker_33, Confidence: 0.9953, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: fb1914f1.jpg, Predicted Class: tracker_33, Confidence: 0.9979, Result: valid
# Folder: tracker_33, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_4
# 1/1 [==============================] - 0s 38ms/step
# Image: 02ec5264.jpg, Predicted Class: tracker_4, Confidence: 0.9428, Result: valid
# 1/1 [==============================] - 0s 41ms/step
# Image: 0c0c8920.jpg, Predicted Class: tracker_4, Confidence: 0.9830, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 18464c05.jpg, Predicted Class: tracker_4, Confidence: 0.9669, Result: valid
# 1/1 [==============================] - 0s 50ms/step
# Image: 2d1c88ce.jpg, Predicted Class: tracker_4, Confidence: 0.9876, Result: valid
# 1/1 [==============================] - 0s 41ms/step
# Image: 4bd073f4.jpg, Predicted Class: tracker_4, Confidence: 0.9560, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 56fce558.jpg, Predicted Class: tracker_4, Confidence: 0.8981, Result: invalid
# 1/1 [==============================] - 0s 38ms/step
# Image: 6150c43f.jpg, Predicted Class: tracker_4, Confidence: 0.9534, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 74be3b11.jpg, Predicted Class: tracker_4, Confidence: 0.9794, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 81849035.jpg, Predicted Class: tracker_4, Confidence: 0.9501, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 87598309.jpg, Predicted Class: tracker_4, Confidence: 0.9871, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 8ef5a07e.jpg, Predicted Class: tracker_4, Confidence: 0.9810, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 918a98eb.jpg, Predicted Class: tracker_4, Confidence: 0.9748, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: bc8e6fe1.jpg, Predicted Class: tracker_4, Confidence: 0.9576, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: c9525b10.jpg, Predicted Class: tracker_4, Confidence: 0.9423, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d2c373a2.jpg, Predicted Class: tracker_4, Confidence: 0.9812, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d7a31a48.jpg, Predicted Class: tracker_4, Confidence: 0.9526, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e40cf682.jpg, Predicted Class: tracker_4, Confidence: 0.9685, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e9018b3e.jpg, Predicted Class: tracker_4, Confidence: 0.9718, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: ebbd2033.jpg, Predicted Class: tracker_4, Confidence: 0.9295, Result: valid
# 1/1 [==============================] - 0s 47ms/step
# Image: ed4288df.jpg, Predicted Class: tracker_4, Confidence: 0.9607, Result: valid
# Folder: tracker_4, Valid Percentage: 95.00%, Result: valid
#
# Processing images in folder: tracker_42
# 1/1 [==============================] - 0s 37ms/step
# Image: 1f0b9925.jpg, Predicted Class: tracker_42, Confidence: 0.9597, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 24301571.jpg, Predicted Class: tracker_42, Confidence: 0.9545, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 8a14f30a.jpg, Predicted Class: tracker_42, Confidence: 0.9705, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 8f42d8ac.jpg, Predicted Class: tracker_42, Confidence: 0.9737, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: c1721cf1.jpg, Predicted Class: tracker_42, Confidence: 0.9651, Result: valid
# Folder: tracker_42, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_43
# 1/1 [==============================] - 0s 36ms/step
# Image: 0f238b07.jpg, Predicted Class: tracker_43, Confidence: 0.9804, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 2aadd1af.jpg, Predicted Class: tracker_43, Confidence: 0.9952, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 4aecf929.jpg, Predicted Class: tracker_43, Confidence: 0.9986, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 4f1a19e8.jpg, Predicted Class: tracker_43, Confidence: 0.9701, Result: valid
# 1/1 [==============================] - 0s 41ms/step
# Image: 70184e5b.jpg, Predicted Class: tracker_43, Confidence: 0.9981, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 8c83e6e2.jpg, Predicted Class: tracker_43, Confidence: 0.9679, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: bfb6d092.jpg, Predicted Class: tracker_43, Confidence: 0.9977, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e266bee4.jpg, Predicted Class: tracker_43, Confidence: 0.9982, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: e2c1efb1.jpg, Predicted Class: tracker_43, Confidence: 0.9985, Result: valid
# Folder: tracker_43, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_5
# 1/1 [==============================] - 0s 38ms/step
# Image: 07ffc66a.jpg, Predicted Class: tracker_5, Confidence: 0.9991, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 118e5b17.jpg, Predicted Class: tracker_5, Confidence: 0.9993, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: 13e965eb.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 235c8878.jpg, Predicted Class: tracker_5, Confidence: 0.9993, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 29e6d4b9.jpg, Predicted Class: tracker_5, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 4299b5f0.jpg, Predicted Class: tracker_5, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: 5d4644f7.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 6b6968bc.jpg, Predicted Class: tracker_5, Confidence: 0.9993, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 72672892.jpg, Predicted Class: tracker_5, Confidence: 0.9995, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 79b9ed75.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 8a62f311.jpg, Predicted Class: tracker_5, Confidence: 0.9995, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 9fa7e8aa.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: a405fcab.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: a9e626ea.jpg, Predicted Class: tracker_5, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: b15f8de7.jpg, Predicted Class: tracker_5, Confidence: 0.9992, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: c4daee13.jpg, Predicted Class: tracker_5, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d1c9fe3f.jpg, Predicted Class: tracker_5, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d1cd4267.jpg, Predicted Class: tracker_5, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 45ms/step
# Image: df083924.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: f3fd0fa4.jpg, Predicted Class: tracker_5, Confidence: 0.9994, Result: valid
# Folder: tracker_5, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_56
# 1/1 [==============================] - 0s 35ms/step
# Image: 01e83ac1.jpg, Predicted Class: tracker_56, Confidence: 0.9983, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 16860637.jpg, Predicted Class: tracker_56, Confidence: 0.9961, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 19c8da12.jpg, Predicted Class: tracker_56, Confidence: 0.9976, Result: valid
# 1/1 [==============================] - 0s 40ms/step
# Image: 1be96c00.jpg, Predicted Class: tracker_56, Confidence: 0.9716, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 1fb37848.jpg, Predicted Class: tracker_56, Confidence: 0.9939, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 214cebe4.jpg, Predicted Class: tracker_56, Confidence: 0.9732, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 4c2a67b6.jpg, Predicted Class: tracker_56, Confidence: 0.9981, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 7a00063b.jpg, Predicted Class: tracker_56, Confidence: 0.9831, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 7b64156b.jpg, Predicted Class: tracker_56, Confidence: 0.9782, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 7fedaf21.jpg, Predicted Class: tracker_56, Confidence: 0.9788, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 892c4431.jpg, Predicted Class: tracker_56, Confidence: 0.9892, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: a8bd1227.jpg, Predicted Class: tracker_56, Confidence: 0.9942, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: d4371d5a.jpg, Predicted Class: tracker_56, Confidence: 0.9601, Result: valid
# Folder: tracker_56, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_61
# 1/1 [==============================] - 0s 36ms/step
# Image: 07bd3cea.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 336b1a47.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 39ms/step
# Image: 4d02a692.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 6bc29454.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 6e7ec8fa.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 6faa8d83.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 7ba0a41e.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 85856711.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 34ms/step
# Image: 8765cf07.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 9af85303.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 9b02def6.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 9b632aa6.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: b60046b4.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: ba9d1957.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: d2800dc8.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: e04c2569.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: e36126c7.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 42ms/step
# Image: f1ada996.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: fb9737ba.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: febf9794.jpg, Predicted Class: tracker_61, Confidence: 1.0000, Result: valid
# Folder: tracker_61, Valid Percentage: 100.00%, Result: valid
#
# Processing images in folder: tracker_62
# 1/1 [==============================] - 0s 37ms/step
# Image: 59c6e56b.jpg, Predicted Class: tracker_62, Confidence: 0.8510, Result: invalid
# 1/1 [==============================] - 0s 36ms/step
# Image: 67fe4d88.jpg, Predicted Class: tracker_62, Confidence: 0.8987, Result: invalid
# 1/1 [==============================] - 0s 36ms/step
# Image: 685519ce.jpg, Predicted Class: tracker_62, Confidence: 0.8622, Result: invalid
# 1/1 [==============================] - 0s 36ms/step
# Image: 7b110f5a.jpg, Predicted Class: tracker_62, Confidence: 0.8960, Result: invalid
# 1/1 [==============================] - 0s 36ms/step
# Image: b3fef690.jpg, Predicted Class: tracker_62, Confidence: 0.9186, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: d2ff3108.jpg, Predicted Class: tracker_62, Confidence: 0.9122, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: f6a2e118.jpg, Predicted Class: tracker_62, Confidence: 0.8104, Result: invalid
# 1/1 [==============================] - 0s 37ms/step
# Image: f878f154.jpg, Predicted Class: tracker_62, Confidence: 0.8590, Result: invalid
# Folder: tracker_62, Valid Percentage: 25.00%, Result: invalid
#
# Processing images in folder: tracker_63
# 1/1 [==============================] - 0s 35ms/step
# Image: 079d6a92.jpg, Predicted Class: tracker_63, Confidence: 0.9976, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 112a69bc.jpg, Predicted Class: tracker_63, Confidence: 0.9960, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 22543e95.jpg, Predicted Class: tracker_63, Confidence: 0.9961, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 3090182d.jpg, Predicted Class: tracker_63, Confidence: 0.9995, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 4daf3ef8.jpg, Predicted Class: tracker_63, Confidence: 0.9989, Result: valid
# 1/1 [==============================] - 0s 36ms/step
# Image: 510cec7c.jpg, Predicted Class: tracker_63, Confidence: 0.9967, Result: valid
# 1/1 [==============================] - 0s 44ms/step
# Image: 62006561.jpg, Predicted Class: tracker_63, Confidence: 0.9962, Result: valid
# 1/1 [==============================] - 0s 41ms/step
# Image: 68b7db9c.jpg, Predicted Class: tracker_63, Confidence: 0.9997, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 6b05933e.jpg, Predicted Class: tracker_63, Confidence: 0.9989, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 70e8cdb3.jpg, Predicted Class: tracker_63, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 772dc6c2.jpg, Predicted Class: tracker_63, Confidence: 0.9990, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: 77d051de.jpg, Predicted Class: tracker_63, Confidence: 0.9977, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 8327912d.jpg, Predicted Class: tracker_63, Confidence: 0.9972, Result: valid
# 1/1 [==============================] - 0s 35ms/step
# Image: 83c388f4.jpg, Predicted Class: tracker_63, Confidence: 0.9978, Result: valid
# 1/1 [==============================] - 0s 38ms/step
# Image: 9f423da6.jpg, Predicted Class: tracker_63, Confidence: 0.9987, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: a2102f22.jpg, Predicted Class: tracker_63, Confidence: 0.9997, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: eaa593c3.jpg, Predicted Class: tracker_63, Confidence: 0.9998, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: eae49137.jpg, Predicted Class: tracker_63, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: eec8828d.jpg, Predicted Class: tracker_63, Confidence: 0.9996, Result: valid
# 1/1 [==============================] - 0s 37ms/step
# Image: f78ca48d.jpg, Predicted Class: tracker_63, Confidence: 0.9973, Result: valid
# Folder: tracker_63, Valid Percentage: 100.00%, Result: valid
